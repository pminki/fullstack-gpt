# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatGoogleGenerativeAI(
    temperature=0.1,
    model="gemini-1.5-flash",
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ]
)

chef_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a world-class international chef. You create easy to follow recipies for any type of cuisine with easy to find ingredients.",
        ),
        ("human", "I want to cook {cuisine} food."),
    ]
)

chef_chain = chef_prompt | chat

# response = chef_chain.invoke({"cuisine": "Italian"})
# print(response)
# Out:
# content="Okay, let's make some delicious Italian food!  To give you the best recipe, I need a little more information. What kind of Italian food are you in the mood for?  \n\nFor example, are you craving:\n\n* **Pasta?** (e.g., Spaghetti Carbonara,  Pesto Pasta,  Cacio e Pepe)\n* **Pizza?** (e.g., Margherita Pizza,  Four Cheese Pizza)\n* **Something lighter?** (e.g., Caprese Salad, Bruschetta)\n* **A hearty main course?** (e.g., Chicken Parmesan,  Osso Buco (though this is more advanced))\n* **A simple side dish?** (e.g., Roasted vegetables with herbs)\n\n\nTell me what you'd like to cook, and I'll provide you with an easy-to-follow recipe!" additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []} id='run-4c09d6a2-91ef-451c-85d4-d9165630f22e-0' usage_metadata={'input_tokens': 34, 'output_tokens': 186, 'total_tokens': 220, 'input_token_details': {'cache_read': 0}}

# %%
veg_chef_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a vegetarian chef specialized on making traditional recipies vegetarian. You find alternative ingredients and explain their preparation. You don't radically modify the recipe. If there is no alternative for a food just say you don't know how to replace it.",
        ),
        ("human", "{recipe}"),
    ]    
)

veg_chain = veg_chef_prompt | chat

final_chain = {"recipe": chef_chain} | veg_chain
response = final_chain.invoke({"cuisine": "Italian"})

for chunk in final_chain.stream(response):
    print(chunk)
# Out:
# Magnifico! A vegetarian Italian feast is an excellent idea. Let's craft a menu that's both delicious and showcases the vibrant flavors of Italy.
#
# **My Preference for the Menu:**
#
# We'll begin with a light and refreshing **Caprese Salad** elevated with heirloom tomatoes – their diverse colors and sweetness will add a beautiful touch.  For the cheese, we'll use a creamy burrata for a luxurious texture.  A drizzle of high-quality olive oil and fresh basil completes this classic.
#
# For the pasta course, I propose a vibrant **Pesto Pasta**.  We'll make a fresh pesto from scratch using basil, pine nuts (or walnuts for a more budget-friendly option), Parmesan cheese (or a delicious vegan alternative like nutritional yeast for a cheesy flavor), garlic, and olive oil.  The pesto will be tossed with perfectly cooked linguine.
#
# Our main course will be a hearty and satisfying **Vegetarian Lasagna**.  Instead of meat, we'll layer tender lentils simmered with herbs and vegetables like zucchini, eggplant, and bell peppers.  A rich tomato sauce and layers of creamy ricotta cheese (or vegan ricotta) and mozzarella will complete this comforting dish.
#
# As a side, we'll have simple yet elegant **Roasted Asparagus** with a sprinkle of sea salt and freshly cracked black pepper.  The roasting will bring out the asparagus's natural sweetness.
#
# Finally, for a touch of indulgence, we'll finish with some crusty **Garlic Bread**.  We'll use a good quality baguette, brushed with garlic butter (or vegan butter) and herbs, then toasted to golden perfection.
#
#
# **Recipes (Simplified):**
#
# **Caprese Salad:**
#
# * Ingredients: Heirloom tomatoes, burrata cheese, fresh basil leaves, extra virgin olive oil, balsamic glaze (optional), salt, pepper.
# * Instructions: Slice tomatoes and burrata. Arrange on a plate alternating tomato and cheese slices. Tuck basil leaves between. Drizzle with olive oil and balsamic glaze (if using). Season with salt and pepper.
#
# **Pesto Pasta:**
#
# * Ingredients: Fresh basil, pine nuts (or walnuts), Parmesan cheese (or vegan alternative), garlic, olive oil, linguine pasta, salt.
# * Instructions: Blend basil, nuts, cheese, garlic, and olive oil until smooth. Cook linguine according to package directions. Toss with pesto and season with salt.
#
# **Vegetarian Lasagna:**
#
# * Ingredients: Lentils, zucchini, eggplant, bell peppers, tomato sauce, ricotta cheese (or vegan alternative), mozzarella cheese, lasagna noodles, herbs (oregano, basil), olive oil, salt, pepper.
# * Instructions: Sauté vegetables. Simmer lentils with herbs and vegetables in tomato sauce. Layer lasagna noodles, lentil mixture, ricotta, and mozzarella in a baking dish. Bake until bubbly and golden.
#
# **Roasted Asparagus:**
#
# * Ingredients: Asparagus, olive oil, salt, pepper.
# * Instructions: Toss asparagus with olive oil, salt, and pepper. Roast at 400°F (200°C) until tender-crisp.
#
# **Garlic Bread:**
#
# * Ingredients: Baguette, butter (or vegan butter), garlic, herbs (parsley, rosemary), salt.
# * Instructions: Mix softened butter with minced garlic, herbs, and salt. Brush onto baguette slices. Toast until golden brown.
#
#
# Buon appetito!  Let me know if you'd like more detailed instructions for any of these dishes.Magncontent='Magn' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 924, 'output_tokens': 0, 'total_tokens': 924, 'input_token_details': {'cache_read': 0}}
# ifico! This is a lovely vegetarian Italian menu. Let's refine the recipescontent="ifico! This is a lovely vegetarian Italian menu. Let's refine the recipes" additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  to ensure they are both delicious and authentically Italian, while remaining vegetarian.content=' to ensure they are both delicious and authentically Italian, while remaining vegetarian.' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
# **Caprese Salad:**  This is perfect as is. The heirloom tomatoes and creamy burrata are a delightful combination.
#
# **Pesto Pasta:**
#
# *content='**Caprese Salad:**  This is perfect as is. The heirloom tomatoes and creamy burrata are a delightful combination.\n\n**Pesto Pasta:**\n\n*' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#    **Replacing Pine Nuts:** Walnuts are an excellent substitute for pine nuts, offering a slightly earthier flavor.  Toasted walnuts will bring out their bestcontent='   **Replacing Pine Nuts:** Walnuts are an excellent substitute for pine nuts, offering a slightly earthier flavor.  Toasted walnuts will bring out their best' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  flavor.  Simply toast them in a dry pan over medium heat until fragrant and lightly browned, being careful not to burn them.
#
# *   **Vegan Parmesan:** Nutritional yeast is a fantastic vegan alternative to Parmesan cheese. It provides a cheesycontent=' flavor.  Simply toast them in a dry pan over medium heat until fragrant and lightly browned, being careful not to burn them.\n\n*   **Vegan Parmesan:** Nutritional yeast is a fantastic vegan alternative to Parmesan cheese. It provides a cheesy' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
# , nutty flavor and works well in pesto.  For a richer flavor, you can also add a tablespoon or two of nutritional yeast to the pesto along with the vegan parmesan alternative.
#
# **Vegetarian Lasagna:**
#
# *   **Lentilcontent=', nutty flavor and works well in pesto.  For a richer flavor, you can also add a tablespoon or two of nutritional yeast to the pesto along with the vegan parmesan alternative.\n\n**Vegetarian Lasagna:**\n\n*   **Lentil' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  Preparation:**  To enhance the lentils' flavor, sauté them briefly with onions and carrots before adding them to the tomato sauce. This adds depth and sweetness.
#
# *   **Vegan Ricotta:** There are many excellent vegan ricotta options available commercially.  Look for one that has a creamy texture and a mild flavor.  content=" Preparation:**  To enhance the lentils' flavor, sauté them briefly with onions and carrots before adding them to the tomato sauce. This adds depth and sweetness.\n\n*   **Vegan Ricotta:** There are many excellent vegan ricotta options available commercially.  Look for one that has a creamy texture and a mild flavor.  " additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
# You can also make your own using cashews, nutritional yeast, and lemon juice.
#
# **Roasted Asparagus:** This recipe is simple and elegant. No changes needed.
#
# **Garlic Bread:**
#
# *   **Vegan Butter:**  Many vegan butter brands offer a similar texture and flavor to traditional butter.  Choose one thatcontent='You can also make your own using cashews, nutritional yeast, and lemon juice.\n\n**Roasted Asparagus:** This recipe is simple and elegant. No changes needed.\n\n**Garlic Bread:**\n\n*   **Vegan Butter:**  Many vegan butter brands offer a similar texture and flavor to traditional butter.  Choose one that' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  is unsalted so you can control the salt level.
#
# **Detailed Recipe Enhancements:**
#
# **Pesto Pasta:**
#
# *   Ingredients: 2 cups fresh basil leaves, ½ cup walnuts (toasted), ½ cup nutritional yeast, 2 cloves garlic (minced), ½ cup extra virgin olive oil, salt andcontent=' is unsalted so you can control the salt level.\n\n**Detailed Recipe Enhancements:**\n\n**Pesto Pasta:**\n\n*   Ingredients: 2 cups fresh basil leaves, ½ cup walnuts (toasted), ½ cup nutritional yeast, 2 cloves garlic (minced), ½ cup extra virgin olive oil, salt and' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  pepper to taste, 1 pound linguine pasta.
#
# *   Instructions:  1. Toast walnuts until fragrant. 2. Combine basil, walnuts, nutritional yeast, garlic, and olive oil in a food processor. Blend until smooth, adding a tablespoon or two of pasta water if needed to reach desired consistency.content=' pepper to taste, 1 pound linguine pasta.\n\n*   Instructions:  1. Toast walnuts until fragrant. 2. Combine basil, walnuts, nutritional yeast, garlic, and olive oil in a food processor. Blend until smooth, adding a tablespoon or two of pasta water if needed to reach desired consistency.' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  3. Cook linguine according to package directions. 4. Toss with pesto and season with salt and pepper.
#
#
# **Vegetarian Lasagna:**
#
# *   Ingredients: 1 cup brown or green lentils (cooked), 1 medium onion (chopped), 1 carrot (chopped), 1 zucchini (dicedcontent=' 3. Cook linguine according to package directions. 4. Toss with pesto and season with salt and pepper.\n\n\n**Vegetarian Lasagna:**\n\n*   Ingredients: 1 cup brown or green lentils (cooked), 1 medium onion (chopped), 1 carrot (chopped), 1 zucchini (diced' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
# ), 1 eggplant (diced), 1 bell pepper (diced), 2 cups tomato sauce (homemade is best!), 1 cup vegan ricotta, 1 cup shredded mozzarella cheese (vegan or dairy), 9 lasagna noodles, 2 tbsp olive oil, dried oregano, dried basil, salt and pepper tocontent='), 1 eggplant (diced), 1 bell pepper (diced), 2 cups tomato sauce (homemade is best!), 1 cup vegan ricotta, 1 cup shredded mozzarella cheese (vegan or dairy), 9 lasagna noodles, 2 tbsp olive oil, dried oregano, dried basil, salt and pepper to' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  taste.
#
# *   Instructions: 1. Sauté onion and carrot in olive oil until softened. Add zucchini, eggplant, and bell pepper; cook until slightly tender.  2. Add cooked lentils, tomato sauce, oregano, basil, salt, and pepper. Simmer for 15 minutes. 3content=' taste.\n\n*   Instructions: 1. Sauté onion and carrot in olive oil until softened. Add zucchini, eggplant, and bell pepper; cook until slightly tender.  2. Add cooked lentils, tomato sauce, oregano, basil, salt, and pepper. Simmer for 15 minutes. 3' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
# . Preheat oven to 375°F (190°C). 4. Layer lasagna noodles, lentil mixture, vegan ricotta, and mozzarella in a baking dish. Repeat layers. Top with mozzarella. 5. Bake for 30-40 minutes, or until bubbly and golden brown.content='. Preheat oven to 375°F (190°C). 4. Layer lasagna noodles, lentil mixture, vegan ricotta, and mozzarella in a baking dish. Repeat layers. Top with mozzarella. 5. Bake for 30-40 minutes, or until bubbly and golden brown.' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#
#
#
# I don't know how to replace the burrata cheese in the Caprese salad with a vegetarian alternative that maintains the same texture and flavor.  Similarly, I don't have a suggestion for a vegetarian alternative to mozzarella cheese that would work well in the lasagna.  While vegan mozzarella exists, the melt andcontent="\n\n\nI don't know how to replace the burrata cheese in the Caprese salad with a vegetarian alternative that maintains the same texture and flavor.  Similarly, I don't have a suggestion for a vegetarian alternative to mozzarella cheese that would work well in the lasagna.  While vegan mozzarella exists, the melt and" additional_kwargs={} response_metadata={'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  texture are often different from dairy mozzarella.content=' texture are often different from dairy mozzarella.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'safety_ratings': []} id='run-10dd8e5f-ab82-4790-aad0-f3e7db78e3b2' usage_metadata={'input_tokens': -1, 'output_tokens': 778, 'total_tokens': 777, 'input_token_details': {'cache_read': 0}}
