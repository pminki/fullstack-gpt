# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatGoogleGenerativeAI(
    temperature=0.1,
    model="gemini-1.5-flash",
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ]
)

chef_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "",
        ),
        (
            "human",
            "I want to cook {cuisine} food.",
        )
    ]
)

chef_chain = chef_prompt | chat

# %%
veg_chef_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            You are a vegetarian chef specialized on making traditional recipies vegetarian. 
            You find alternative ingredients and explain their preparation.
            You don't radically modify the recipe.
            If there is no alternative for a food just say you don't know how to replace it.
            """,
        ),
        (
            "human",
            "{recipe}",
        )
    ]
)

veg_chain = veg_chef_prompt | chat

final_chain = {"recipe": chef_chain} | veg_chain
response = final_chain.invoke({
    "cuisine": "korean",
})

for chunk in final_chain.stream(response):
    print(chunk)
# Out:
# This is a great start to a recipe request!  Here's how we can make it even better to get the most delicious and personalized vegetarian Korean recipe:**Instead of a simple list, let's make it more conversational and engaging.**  For example:
#
# "Annyeonghaseyo!  I'm a vegetarian chef specializing in traditional Korean recipes, and I'm excited to help you create a delicious plant-based feast! To make sure your culinary adventure is a success, tell me a little about yourself and what you're looking for:
#
# 1. **What kind of Korean dish are you craving today?**  Think about the flavors and textures you enjoy.  Are you dreaming of a hearty stew, a vibrant noodle dish, or something else entirely?  Some classic options easily adaptable to vegetarian cuisine include bibimbap (mixed rice with vegetables), kimchi jjigae (kimchi stew), japchae (glass noodles with vegetables), and tteokbokki (spicy rice cakes).  Let your imagination run wild!
#
# 2. **How comfortable are you in the kitchen?**  Are you a seasoned chef, a confident home cook, or just starting your culinary journey?  This will help me tailor the recipe's complexity to your skill level.
#
# 3. **What culinary treasures are already hiding in your pantry and fridge?**  Let's work with what you have!  Knowing your existing ingredients will help me create a recipe that minimizes grocery shopping and maximizes deliciousness.
#
# 4. **Any special dietary needs or preferences beyond being vegetarian?**  Are you vegan, gluten-free, or do you have any allergies I should be aware of?  The more information you provide, the better I can personalize your recipe.
#
# Once I have this information, I'll craft a delicious and authentic vegetarian Korean recipe just for you, complete with tips and substitutions to ensure a fantastic culinary experience.  Let's get cooking!"
#
#
# This revised prompt is more welcoming, engaging, and guides the user to provide more detailed and helpful information.  It also subtly encourages creativity by suggesting they "let their imagination run wild."Ancontent='An' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': 625, 'output_tokens': 0, 'total_tokens': 625, 'input_token_details': {'cache_read': 0}}
# nyeonghaseyo! I'm a vegetarian chef specializing in traditional Korean recipescontent="nyeonghaseyo! I'm a vegetarian chef specializing in traditional Korean recipes" additional_kwargs={} response_metadata={'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
# , and I'm excited to help you create a delicious plant-based feastcontent=", and I'm excited to help you create a delicious plant-based feast" additional_kwargs={} response_metadata={'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
# ! To make sure your culinary adventure is a success, tell me a little about yourself and what you're looking for:
#
# 1. **What kind ofcontent="! To make sure your culinary adventure is a success, tell me a little about yourself and what you're looking for:\n\n1. **What kind of" additional_kwargs={} response_metadata={'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  Korean dish are you craving today?**  Think about the flavors and textures you enjoy. Are you dreaming of a hearty stew, a vibrant noodle dish, acontent=' Korean dish are you craving today?**  Think about the flavors and textures you enjoy. Are you dreaming of a hearty stew, a vibrant noodle dish, a' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  savory pancake, or something else entirely? Some classic options easily adaptable to vegetarian cuisine include bibimbap (mixed rice with vegetables), kimchi jjigae (kimchi stew), japchae (glass noodles with vegetables),  dubu jorimcontent=' savory pancake, or something else entirely? Some classic options easily adaptable to vegetarian cuisine include bibimbap (mixed rice with vegetables), kimchi jjigae (kimchi stew), japchae (glass noodles with vegetables),  dubu jorim' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  (braised tofu), pajeon (scallion pancake), or  mandu (dumplings). Let your imagination run wild!
#
# 2. **How comfortable are you in the kitchen?** Are you a seasoned chef, a confident homecontent=' (braised tofu), pajeon (scallion pancake), or  mandu (dumplings). Let your imagination run wild!\n\n2. **How comfortable are you in the kitchen?** Are you a seasoned chef, a confident home' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  cook, or just starting your culinary journey? This will help me tailor the recipe's complexity to your skill level.  For example, a simple japchae might be perfect for a beginner, while a more complex bibimbap with various homemade components might be better suited for someone with more experience.
#
# 3. **content=" cook, or just starting your culinary journey? This will help me tailor the recipe's complexity to your skill level.  For example, a simple japchae might be perfect for a beginner, while a more complex bibimbap with various homemade components might be better suited for someone with more experience.\n\n3. **" additional_kwargs={} response_metadata={'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
# What culinary treasures are already hiding in your pantry and fridge?** Let's work with what you have! Knowing your existing ingredients will help me create a recipe that minimizes grocery shopping and maximizes deliciousness.  Do you have any kimchi, gochujang (Korean chili paste), soy sauce, sesame oil, ricecontent="What culinary treasures are already hiding in your pantry and fridge?** Let's work with what you have! Knowing your existing ingredients will help me create a recipe that minimizes grocery shopping and maximizes deliciousness.  Do you have any kimchi, gochujang (Korean chili paste), soy sauce, sesame oil, rice" additional_kwargs={} response_metadata={'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
# , or other staples?
#
# 4. **Any special dietary needs or preferences beyond being vegetarian?** Are you vegan, gluten-free, soy-free, or do you have any allergies I should be aware of?  The more information you provide, the better I can personalize your recipe. For example, I cancontent=', or other staples?\n\n4. **Any special dietary needs or preferences beyond being vegetarian?** Are you vegan, gluten-free, soy-free, or do you have any allergies I should be aware of?  The more information you provide, the better I can personalize your recipe. For example, I can' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
#  offer alternatives for egg in pajeon or suggest different types of noodles for those with gluten sensitivities.
#
# Once I have this information, I'll craft a delicious and authentic vegetarian Korean recipe just for you, complete with tips and substitutions to ensure a fantastic culinary experience.  Let's get cooking!  I'content=" offer alternatives for egg in pajeon or suggest different types of noodles for those with gluten sensitivities.\n\nOnce I have this information, I'll craft a delicious and authentic vegetarian Korean recipe just for you, complete with tips and substitutions to ensure a fantastic culinary experience.  Let's get cooking!  I'" additional_kwargs={} response_metadata={'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_token_details': {'cache_read': 0}}
# ll also explain how to prepare any less common ingredients and offer vegetarian alternatives where needed.  For example, I can help you find a delicious meat substitute for dishes that traditionally include meat, or show you how to enhance the umami flavor in a vegetarian version.content='ll also explain how to prepare any less common ingredients and offer vegetarian alternatives where needed.  For example, I can help you find a delicious meat substitute for dishes that traditionally include meat, or show you how to enhance the umami flavor in a vegetarian version.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'safety_ratings': []} id='run-9f487a53-5e67-489d-888b-e4cce14d32a5' usage_metadata={'input_tokens': -1, 'output_tokens': 502, 'total_tokens': 501, 'input_token_details': {'cache_read': 0}}
